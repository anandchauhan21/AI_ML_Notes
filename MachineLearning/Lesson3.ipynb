# %% [markdown]
# <a href="https://colab.research.google.com/github/anandchauhan21/AI_ML_Notes/blob/main/MachineLearning/Lesson3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🤖 Lesson 3: Machine Learning Workflow
#
# ## 🎯 Objectives
# By the end of this lesson, you will be able to:
# - Understand the **end-to-end ML workflow**
# - Identify each stage from **data to deployment**
# - Build a **simple ML pipeline** in Python
# - Know common mistakes in ML projects

# %% [markdown]
# # 🧠 Concept Recap — ML Workflow
#
# A Machine Learning workflow is the **step-by-step process**
# to build, evaluate, and deploy an ML model.
#
# ---
#
# ## 🔁 ML Workflow Steps
#
# 1. **Problem Definition**
# 2. **Data Collection**
# 3. **Data Preprocessing**
# 4. **Exploratory Data Analysis (EDA)**
# 5. **Model Selection**
# 6. **Model Training**
# 7. **Model Evaluation**
# 8. **Model Deployment**
# 9. **Monitoring & Improvement**

# %% [markdown]
# ## 🔄 ML Workflow Flow
#
# Data → Preprocessing → Model → Evaluation → Deployment → Feedback → Improvement

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
# Simple dataset
data = {
    "Hours": [1,2,3,4,5,6],
    "Marks": [35,40,50,60,65,75]
}
df = pd.DataFrame(data)
df

# %%
X = df[['Hours']]
y = df['Marks']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
model = LinearRegression()
model.fit(X_train, y_train)

# %%
pred = model.predict(X_test)
print("MSE:", mean_squared_error(y_test, pred))

# %%
print("Predicted marks for 7 hours:", model.predict([[7]])[0])

# %% [markdown]
# # 🧩 Lesson Recap
#
# You learned:
# ✅ Complete ML workflow
# ✅ Importance of each step
# ✅ Built a mini ML pipeline
# ✅ Evaluated a simple model
#
# ---
#
# ### 🔜 Next Lesson:
# **Lesson 4: Mathematics for Machine Learning (Linear Algebra)**

# %% [markdown]
# ## 💬 Viva Questions
#
# 1. What is the first step in the ML workflow?
# 2. Why is data preprocessing important?
# 3. What is train-test split?
# 4. What happens after deployment?
# 5. What is model evaluation?
